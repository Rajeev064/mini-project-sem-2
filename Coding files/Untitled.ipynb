# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

file = "RELIANCE.csv"
df = pd.read_csv(file)

plt.figure(figsize=(12,12))
sns.heatmap(df.isnull(),cmap='magma')

# %%
df.dropna(inplace = True)
print(df.isna().sum())
print(df.info())
df['Date'] = pd.to_datetime(df.Date,format='%Y-%m-%d')
df.index = df['Date']
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2461 entries, 0 to 2467
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2461 non-null   object
#  1   Open       2461 non-null   float64
#  2   High       2461 non-null   float64
#  3   Low        2461 non-null   float64
#  4   Close      2461 non-null   float64
#  5   Adj Close  2461 non-null   float64
#  6   Volume     2461 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 153.8+ KB
# None

# %%
plt.figure(figsize=(16,8))
plt.plot(df['Close'], label='Close Price history')
plt.plot(df['Adj Close'], label='Close Price history')

# %%
X = df['Open'].values.reshape(-1,1);
# X = df[['Open','High','Low']];
y = df['Close'].values.reshape(-1,1);
print(type(X))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)
# Out:
# <class 'numpy.ndarray'>

# %%
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train,y_train)
# model.score(X_test,y_test)
# model.predict([[2128.00]])
# ans = model.predict(X_test)

# # plt.figure(figsize=(20,15))
# # plt.plot(y_test, label='Close Price history')
# # plt.plot(ans, label='Close Price history')


# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_test, ans)
# X = df[['High','Low','Close']];
# print(X.head(5))
# X.drop(X.head(1).index, inplace=True)
# print(X.head(5))
# y = df['Open'].values.reshape(-1,1);
# print(y[0])
# y = np.delete(y, [0])
# print(y[0])
# print(type(X))

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# model.fit(X_train,y_train)
# print(model.score(X_test,y_test))
# ans = model.predict(X_test)

# # plt.figure(figsize=(20,15))
# # plt.plot(y_test, label='Close Price history')
# # plt.plot(ans, label='Close Price history')


# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_test, ans)
# print(model.predict([[2336.00,2247.35,2255.85]]))


# # for i in range(len(X_test)):
# # 2,072.20
# #     print("{}-{}".format(y[i],y_test[i]))
# Out:
#                   High         Low       Close
# Date
# 2010-07-27  530.575012  525.549988  526.750000
# 2010-07-28  536.825012  509.000000  510.625000
# 2010-07-29  514.250000  504.000000  505.075012
# 2010-07-30  510.174988  503.625000  504.825012
# 2010-08-02  510.899994  505.700012  507.274994
#                   High         Low       Close
# Date
# 2010-07-28  536.825012  509.000000  510.625000
# 2010-07-29  514.250000  504.000000  505.075012
# 2010-07-30  510.174988  503.625000  504.825012
# 2010-08-02  510.899994  505.700012  507.274994
# 2010-08-03  515.450012  507.000000  513.875000
# [529.424988]
# 531.5
# <class 'pandas.core.frame.DataFrame'>
# 0.999739480148433
# [2319.36481305]
# C:\Python\Python38\lib\site-packages\pandas\core\frame.py:3987: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
X = df[['Open','High','Low']];
print(type(X))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=20)

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
print(model.score(X_test,y_test))
ans = model.predict(X_test)

# plt.figure(figsize=(20,15))
# plt.plot(y_test, label='Close Price history')
# plt.plot(ans, label='Close Price history')


from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, ans)
print(model.predict([[6395.00,6518.55,6331.00]]))
# for i in range(len(X_test)):
# 2,072.20
#     print("{}-{}".format(y[i],y_test[i]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 0.9998365485514871
# [[2148.07444985]]

# %%
# from sklearn.svm import SVR

# regr = SVR()
# regr.fit(X_train, y_train)
# print(regr.score(X_test,y_test))
# ans = model.predict(X_test)

# # plt.figure(figsize=(20,15))
# # plt.plot(y_test, label='Close Price history')
# # plt.plot(ans, label='Close Price history')


# from sklearn.metrics import mean_squared_error
# mean_squared_error(y_test, ans)

# # regr.predict(np.array([[2083.55]]))

# %%
import pickle

# %%
pickle.dump(model,open('rel.pkl','wb'))

# %%
rg = pickle.load(open('rel.pkl','rb'))

# %%
rg.predict([[2085.00,2167.80,2081.45]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-cfef115ce282> in <module>
# ----> 1 rg.predict(2085.00,2167.80,2081.45)
#
# TypeError: predict() takes 2 positional arguments but 4 were given

# %%
object = pd.read_pickle(r'rel.pkl')

# %%
object
# Out:
# LinearRegression()
